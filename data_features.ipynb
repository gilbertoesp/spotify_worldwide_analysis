# %% [markdown]
# # Spotify  Features - Reconocimiento de Patrones
# ## Gilberto Espinoza

# %%
import pandas as pd
import numpy as np
import spotify
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_ranking = pd.read_csv("data/data.csv")
df_ranking.head(10)
# Out:
#    Position                  Track Name           Artist  Streams  \
# 0         1  Reggaetón Lento (Bailemos)             CNCO    19272
# 1         2                    Chantaje          Shakira    19270
# 2         3   Otra Vez (feat. J Balvin)    Zion & Lennox    15761
# 3         4                Vente Pa' Ca     Ricky Martin    14954
# 4         5                      Safari         J Balvin    14269
# 5         6                La Bicicleta     Carlos Vives    12843
# 6         7                  Ay Mi Dios         IAmChino    10986
# 7         8          Andas En Mi Cabeza    Chino & Nacho    10653
# 8         9                 Traicionera  Sebastian Yatra     9807
# 9        10                 Shaky Shaky     Daddy Yankee     9612
#
#                                                  URL        Date Region
# 0  https://open.spotify.com/track/3AEZUABDXNtecAO...  2017-01-01     ec
# 1  https://open.spotify.com/track/6mICuAdrwEjh6Y6...  2017-01-01     ec
# ...

# %%
df_features = pd.read_csv("data/features.csv")
print("Cantidad de features disponibles: {}".format(len(df_features)))
df_features.head(5)
# Out:
# Cantidad de features disponibles: 1578379
#    Unnamed: 0  acousticness  \
# 0           0       0.40000
# 1           1       0.18700
# 2           2       0.05590
# 3           3       0.00431
# 4           4       0.55100
#
#                                         analysis_url  danceability  \
# 0  https://api.spotify.com/v1/audio-analysis/3AEZ...         0.761
# 1  https://api.spotify.com/v1/audio-analysis/6mIC...         0.852
# 2  https://api.spotify.com/v1/audio-analysis/3QwB...         0.832
# 3  https://api.spotify.com/v1/audio-analysis/7DM4...         0.663
# 4  https://api.spotify.com/v1/audio-analysis/6rQS...         0.508
#
#    duration_ms  energy                      id  instrumentalness  key  \
# 0       222560   0.838  3AEZUABDXNtecAOSC1qTfo          0.000000    4
# 1       195840   0.773  6mICuAdrwEjh6Y6lroV2Kg          0.000030    8
# 2       209453   0.772  3QwBODjSEzelZyVjxPOHdq          0.000486   10
# ...

# %%
df_features.describe()
# Out:
#          Unnamed: 0  acousticness  danceability   duration_ms        energy  \
# count  1.578379e+06  1.578379e+06  1.578379e+06  1.578379e+06  1.578379e+06
# mean   7.891890e+05  2.110196e-01  6.801944e-01  2.197165e+05  6.728546e-01
# std    4.556389e+05  2.185354e-01  1.270786e-01  3.982600e+04  1.619472e-01
# min    0.000000e+00  6.970000e-06  6.450000e-02  3.206900e+04  2.620000e-03
# 25%    3.945945e+05  4.720000e-02  6.090000e-01  1.959200e+05  5.670000e-01
# 50%    7.891890e+05  1.320000e-01  6.960000e-01  2.145070e+05  6.930000e-01
# 75%    1.183784e+06  3.030000e-01  7.660000e-01  2.369870e+05  8.000000e-01
# max    1.578378e+06  9.950000e-01  9.830000e-01  3.924548e+06  9.990000e-01
#
#        instrumentalness           key      liveness      loudness  \
# count      1.578379e+06  1.578379e+06  1.578379e+06  1.578379e+06
# mean       6.423483e-03  5.211442e+00  1.664844e-01 -5.809810e+00
# std        5.282412e-02  3.676740e+00  1.245276e-01  2.178247e+00
# ...

# %% [markdown]
# Vemos que las columnas que decriben las canciones 'acousticness, danceability, energy, instrumentalness, liveness, loudness, speechiness, valence van de 0 a 1.

# %% [markdown]
# ### Describiendo columnas

# %%
data_acustico = df_features['acousticness'].copy()
data_acustico.describe()
# Out:
# count    1.578379e+06
# mean     2.110196e-01
# std      2.185354e-01
# min      6.970000e-06
# 25%      4.720000e-02
# 50%      1.320000e-01
# 75%      3.030000e-01
# max      9.950000e-01
# Name: acousticness, dtype: float64

# %%
data_acustico.plot(figsize=(15,30))
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# /home/gilbertoesp/anaconda3/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     305                 pass
#     306             else:
# --> 307                 return printer(obj)
#     308             # Finally look for special method names
#     309             method = get_real_method(obj, self.print_method)
#
# /home/gilbertoesp/anaconda3/lib/python3.6/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     238
#     239     if 'png' in formats:
# --> 240         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     241     if 'retina' in formats or 'png2x' in formats:
#     242         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ...

# %% [markdown]
# ### Conteo de etiquetas

# %%
# Contabiliza etiquetas
def get_counters(col_name, label):
    full_list = ";".join(col_name)
    each_word = full_list.split(";")
    each_word = Counter(each_word).most_common()
    return pd.DataFrame(each_word, columns = [label, "Participantes"])

# Calcular porcentajes
def percent (row, col):
    count = df[col].count()
    return 100 * row[1] / count
